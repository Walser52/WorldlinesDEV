# %%
import sympy as sp

# %%
# Out:
# /home/fes33/anaconda3/bin/python

# %%
x = sp.symbols('x')
sp.plot_parametric((x, sp.sin(1/(x))), (x,0, 1))

# %% [markdown]
# ![image.png](attachment:image.png)
